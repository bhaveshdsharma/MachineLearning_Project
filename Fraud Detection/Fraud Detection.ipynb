# %%
import pandas as pd 
df = pd.read_csv ("dataset/creditcard.csv")

# %%
import seaborn as sns
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
## Splitting Independent and dependent feature

X = df.drop('Class',axis=1)
y = df.Class

# %%
df.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17
# V2     -0.010593  4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16
# V3     -0.419618 -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16
# V4     -0.105260  1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00
# V5      0.173072  6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15
# V6     -0.063016  2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16
# V7      0.084714  1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16
# V8     -0.036949 -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16
# V9     -0.008660  2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16
# V10     0.030617  7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16
# V11    -0.247689  2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16
# ...

# %%
sns.heatmap(df.corr())

# %%
sns.countplot('Class', data=df)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.20,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
#from sklearn.model_selection import GridSearchCV,KFold

# %%
clf1= RandomForestClassifier()
clf1.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=clf1.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[56854     7]
#  [   21    80]]
# 0.9995084442259752
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.92      0.79      0.85       101
#
#     accuracy                           1.00     56962
#    macro avg       0.96      0.90      0.93     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Before over sampling", Counter(y_train))
# Out:
# Before over sampling Counter({0: 227454, 1: 391})

# %% [markdown]
# # Over sampling

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
from collections import Counter

# %%
ovr_sam=RandomOverSampler(0.75)
# Out:
# C:\Users\Omdutt\anaconda3\lib\site-packages\imblearn\utils\_validation.py:591: FutureWarning: Pass sampling_strategy=0.75 as keyword args. From version 0.9 passing these as positional arguments will result in an error
#   FutureWarning,

# %%
X_train_ovr,y_train_ovr = ovr_sam.fit_resample(X_train,y_train)
print("Before over sampling", Counter(y_train))
print("After over sampling", Counter(y_train_ovr))
# Out:
# Before over sampling Counter({0: 227454, 1: 391})
# After over sampling Counter({0: 227454, 1: 170590})

# %% [markdown]
# ### 227454 * .75 = 170590.5

# %%
from sklearn.ensemble import RandomForestClassifier
clf2= RandomForestClassifier()
clf2.fit(X_train_ovr,y_train_ovr)
# Out:
# RandomForestClassifier()

# %%
y_pred=clf2.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[56855     6]
#  [   19    82]]
# 0.9995611109160493
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.93      0.81      0.87       101
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.91      0.93     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
# y_test.to_numpy()
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)
